# %% [markdown]
# # MedNorm-VI Qwen LoRA and Calibration
#
# Train the constrained critic/adjudicator LoRA and calibration layers. The Qwen proposer must emit only anchored substrings and never final entities or codes.

# %%
from google.colab import drive
drive.mount('/content/drive')
REPO = '/content/drive/MyDrive/mednorm-vi'
CHECKPOINT_ROOT = f'{REPO}/models/checkpoints/full_v1/qwen_lora'
print(CHECKPOINT_ROOT)

# %%
# %cd $REPO
# !env PYTHONPATH=src python3 -m mednorm_vi.training.cli plan --artifact-root models/checkpoints/full_v1
