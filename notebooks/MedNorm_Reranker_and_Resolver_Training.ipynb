# %% [markdown]
# # MedNorm-VI Reranker and Resolver Training
#
# Train boundary/type resolver, ICD/RxNorm rerankers, and calibration heads from reviewed train/dev folds. Resume checkpoints from Drive; export manifests and hashes.

# %%
from google.colab import drive
drive.mount('/content/drive')
REPO = '/content/drive/MyDrive/mednorm-vi'
A100_BATCH_HINT = {'bf16': True, 'gradient_checkpointing': True}
print(REPO, A100_BATCH_HINT)

# %%
# %cd $REPO
# !env PYTHONPATH=src python3 -m mednorm_vi.model_registry.cli --profile full --registry configs/model_registry/models_v1.yaml
