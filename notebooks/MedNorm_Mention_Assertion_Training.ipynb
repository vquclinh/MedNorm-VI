# %% [markdown]
# # MedNorm-VI Mention and Assertion Training
#
# Colab Pro workflow for ViHealthBERT/PhoBERT/XLM-R/GLiNER span models and Assertion Hydra heads. Use mixed precision, deterministic seeds, Drive checkpoints, and resume from existing manifests.

# %%
from google.colab import drive
drive.mount('/content/drive')
REPO = '/content/drive/MyDrive/mednorm-vi'
CHECKPOINT_ROOT = f'{REPO}/models/checkpoints/full_v1'
SEED = 20260717
MIXED_PRECISION = 'bf16'
print(CHECKPOINT_ROOT, SEED, MIXED_PRECISION)

# %%
# %cd $REPO
# !env PYTHONPATH=src python3 -m mednorm_vi.training.cli plan --artifact-root models/checkpoints/full_v1
