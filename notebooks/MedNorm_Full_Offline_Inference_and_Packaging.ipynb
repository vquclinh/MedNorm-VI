# %% [markdown]
# # MedNorm-VI Full Offline Inference and Packaging
#
# Run reviewed local checkpoints and KB indexes through the shared L1-L9 pipeline, validate organizer JSON, and package `output.zip`. Full mode fails if checkpoints are missing.

# %%
from google.colab import drive
drive.mount('/content/drive')
REPO = '/content/drive/MyDrive/mednorm-vi'
OUTPUT_ZIP = f'{REPO}/outputs/output.zip'
print(REPO, OUTPUT_ZIP)

# %%
# %cd $REPO
# !env PYTHONPATH=src python3 -m mednorm_vi.inference.cli run --input-dir data/organizer_test/input --output-zip outputs/output.zip --config configs/pipeline/full_v1.yaml --mode full
