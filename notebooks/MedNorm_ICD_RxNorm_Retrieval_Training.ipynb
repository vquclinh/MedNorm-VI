# %% [markdown]
# # MedNorm-VI ICD/RxNorm Retrieval Training
#
# Build and validate local retrieval artifacts. Dense adapters can be trained after reviewed gold exists; no network or organizer-test labeling is performed here.

# %%
from google.colab import drive
drive.mount('/content/drive')
REPO = '/content/drive/MyDrive/mednorm-vi'
SEED = 20260717
print(REPO, SEED)

# %%
# %cd $REPO
# !env PYTHONPATH=src python3 -m mednorm_vi.kb.indexing.cli build-icd --normalized-csv data/derived/icd10_vi/tt06-2026/icd10_vi_normalized.csv --output-dir indices/icd10_vi/tt06-2026 --snapshot-id icd10-vi-tt06-2026-local
