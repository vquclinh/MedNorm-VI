# %% [markdown]
# # MedNorm-VI Data Engine and Folds
#
# Colab Pro workflow for S0 dataset manifests, exact-offset validation, leakage checks, and fold construction. Persist artifacts under Google Drive and export only manifests/checkpoint metadata back to the repository.

# %%
from google.colab import drive
drive.mount('/content/drive')
REPO = '/content/drive/MyDrive/mednorm-vi'
SEED = 20260717
print(REPO, SEED)

# %%
# %cd $REPO
# !env PYTHONPATH=src python3 -m mednorm_vi.data_engine.cli build-from-text-dir --input-dir data/manual_gold/text --folds 5
